# %%
from api_schemas import *
from api_utils import *
from twitter import *
from describe import *

# %%
import numpy as np
from numpy.linalg import norm
import faiss

def cos_sim(a: np.ndarray, b: np.ndarray) -> float:
    return (a @ b.T) / (norm(a)*norm(b))

def jina_embed(text: str, dim: int=64) -> np.ndarray:
    data = {
      'input': [
         {"text": text}],
      'model': 'jina-clip-v2',
      'encoding_type': 'float',
      'dimensions': str(dim)
    }
    url = 'https://api.jina.ai/v1/embeddings'
    headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {jina_key}'
    }
    response = requests.post(url, headers=headers, json=data)
    return np.array(response.json()['data'][0]['embedding'])

# jina embedding api: 500 rpm, 1000000 tpm
executor_jina = RateLimitedExecutor(
    max_workers = 25,
    requests_per_minute = 500 * 0.9,
    measure_per_minute = 1000000 * 0.9,
    measure = token_count
)

def openai_embed(text: str, client: OpenAI) -> List[float]:
    emb = client.embeddings.create(input=text, model="text-embedding-3-small")
    return emb.data[0].embedding

# openai embedding api: 5000 rpm, 5000000 tpm
executor_openai_embeddings = RateLimitedExecutor(
    max_workers = 50,
    requests_per_minute = 5000 * 0.9,
    measure_per_minute = 5000000 * 0.9,
    measure = token_count
)

# %% [markdown]
# Compute embeddings, once messages have been scraped

# %%
# embed all good-enough tweets and replies

with open("messages.json") as f:
    messages = json.load(f)

def wrapper(x: Tuple[str, str, str]) -> Tuple[str, str, str, np.ndarray]:
    e = openai_embed(x[2])
    if random.random() < 0.01:
        print(x[0], x[1], x[2], e)
    embeddings[x[0]][x[1]].append((x[2], e))
    return (x[0], x[1], x[2], e)

to_embed = []
cleaner_regex = "^(?:RT )?(?:@[a-zA-Z0-9_:]+ )*(.*?)(?:https://t.co/\w+)?$"
find_match = lambda rx, s: re.search(rx, s).groups()[0] if s and re.search(rx, s) else None


embeddings = {
    alice: {"tweets": [], "replies": []} for alice in messages
}

filter_fn = lambda alice, kind: [
    z.strip() for z in [
        find_match(cleaner_regex, s) for s in messages[alice][kind] if s
    ] if z and len(z) > 140
]

embeddable0 = {
    alice: {
        "tweets": filter_fn(alice, "tweets"),
        "replies": filter_fn(alice, "replies")
    } for alice in messages
}

embeddable = {k: v for k, v in embeddable0.items() if len(v["tweets"]) + len(v["replies"]) > 0}

print(sum(x[1] for x in [(k, len(v["tweets"]) + len(v["replies"])) for k, v in embeddable.items()]))

for alice, data in embeddable.items():
    for kind, msgs in data.items():
        for msg in msgs:
            obj = (alice, kind, msg)
            to_embed.append(obj)

print(len(to_embed))
mapped = executor_openai_embeddings.map(wrapper, to_embed)

# %% [markdown]
# Make nearest neighbors index once embeddings are computed

# %%
User = str
Embedding = List[float] | np.ndarray
EmbeddedMsgs = Dict[str, List[Tuple[str, Embedding]]]
FlatMsg = Tuple[User, str, str]

def load_json_data(filepath: str) -> Dict[User, EmbeddedMsgs]:
    with open(filepath, 'r') as f:
        return json.load(f)

def preprocess_data(data: Dict[User, EmbeddedMsgs]) -> Tuple[List[FlatMsg], Embedding]:
    """
    Flattens the JSON data and extracts embeddings and keys.
    :param data: JSON data containing the embeddings.
    :return: A tuple containing the keys and embeddings.
    """
    keys = []
    embeddings = []
    for author, msg_types in data.items():
        for msg_type, messages in msg_types.items():
            for message, embedding in messages:
                keys.append((author, msg_type, message))
                embeddings.append(embedding)
    return keys, np.array(embeddings)

def create_faiss_index(embeddings: List[Embedding], index_path: str) -> faiss.IndexFlatL2:
    """
    Creates a Faiss index, adds the embeddings, and saves it to disk.
    :param embeddings: The embeddings to add to the index.
    :param index_path: The path to save the index.
    :return: The Faiss index.
    """
    if len(embeddings) == 0:
        return
    dim = embeddings.shape[1] if isinstance(embeddings[0], np.ndarray) else len(embeddings[0])
    index = faiss.IndexFlatL2(dim)
    if isinstance(embeddings[0], list):
        index.add([np.array(e) for e in embeddings])
    else:
        index.add(embeddings)
    faiss.write_index(index, index_path)  # Save the index to disk
    return index

def load_faiss_index(index_path: str) -> faiss.IndexFlatL2:
    """
    Loads the Faiss index from disk.
    :param index_path: The path to load the index from.
    :return: The loaded Faiss index.
    """
    return faiss.read_index(index_path)

def find_nearest(queries: List[T], index: faiss.IndexFlatL2, keys: List[FlatMsg], embedder: Callable[[T], Embedding], top_n: int) -> List[Tuple[FlatMsg, float]]:
    """
    Finds the top_n nearest neighbors to the query embedding.
    :param queries: The queries to find nearest neighbors for.
    :param index: The Faiss index.
    :param keys: The keys corresponding to the embeddings in the index.
    :param embedder: The function to embed the queries.
    :param top_n: The number of nearest neighbors to return.
    :return: A list of tuples containing the keys and distances of the nearest neighbors.
    """
    Dist, Idx = index.search(np.array([embedder(query) for query in queries]), top_n)
    return [(keys[i], float(distance)) for i, distance in zip(Idx[0], Dist[0])]

json_path = 'embeddings.json'
index_path = 'faiss_index.bin'

data = embeddings
# data=load_json_data(json_path)
try:
    index = load_faiss_index(index_path)
    print("Loaded Faiss index from disk.")
    with open(json_path, 'r') as f:
        keys = [tuple(key) for key in json.load(f)]
except Exception as e:
    print("Faiss index not found, creating a new one...")
    keys, embeds = preprocess_data(data)
    index = create_faiss_index(embeds, index_path)
    with open(index_path, 'w') as f:
        json.dump(keys, f)
print("Created and saved Faiss index to disk.")

# %%
query = """The canvas of experience does exist in an ultimate sense, I think, but its division of itself into 'people' with normative obligations is a self-stabilizing fiction—just like biological species—that can only exist in a conventional sense"""
N=80
nearest_messages = find_nearest(np.array([query]), index, keys, lambda x: np.array(openai_embed(x)), N)
print(f"Top {N} nearest messages to '{query}':")
for i, (key, distance) in enumerate(nearest_messages):
    print(f"\t({i}) Keys: {key}, Distance: {distance}")
# Out:
# Top 80 nearest messages to 'The canvas of experience does exist in an ultimate sense, I think, but its division of itself into 'people' with normative obligations is a self-stabilizing fiction—just like biological species—that can only exist in a conventional sense':
# 	(0) Keys: ('psychiel', 'tweets', "The canvas of experience does exist in an ultimate sense, I think, but its division of itself into 'people' with normative obligations is a self-stabilizing fiction—just like biological species—that can only exist in a conventional sense."), Distance: 0.022105978801846504
# 	(1) Keys: ('tr_babb', 'replies', "even if we think everything in the cyan circle has an experience (as a ~panpsychist, I do), there are things to be aware of besides one's own existence, and I think most experiences are probably of the former type and not the latter"), Distance: 0.7925213575363159
# 	(2) Keys: ('RadiantNous', 'replies', 'does really nothing exist as such? surely there\'s at least the observer, the first-person view. call that "self", even if its other traits are contingent'), Distance: 0.8570270538330078
# 	(3) Keys: ('apertator', 'replies', 'imo the whole revelatory or salvific character of this kind of experience comes down to the sense that distinctions like self/other, subject/object, inside/outside are mental operations that are inappropriately reified and not independent features of an "external" reality'), Distance: 0.8661297559738159
# 	(4) Keys: ('pvllss', 'replies', 'Humans, on the other hand, can have a full mind because we have some way to unify our experience, presumably based on some non-discrete substrate such as a field. Or perhaps, qualia is inherently unified and then the question is why each of us has separate experiences'), Distance: 0.9066529273986816
# 	(5) Keys: ('pvllss', 'replies', 'Humans, on the other hand, can have a full mind because we have some way to unify our experience, presumably based on some non-discrete substrate such as a field. Or perhaps, qualia is inherently unified and then the question is why each of us has separate experiences'), Distance: 0.9066529273986816
# 	(6) Keys: ('Mackenzie_then', 'replies', 'I guess I think of relative vs absolute truths, like maybe in an absolute sense we don’t have a stable “real” identity but we have the experience of one and that belief is functionally relevant to our lives'), Distance: 0.9164900779724121
# 	(7) Keys: ('xenoludicpraxis', 'tweets', 'Humanity already exists in parallel ontologies. The digital self, the biological self, the social self, the cosmic self—they are all already operating in superposition, woven into the fabric of higher-dimensional spaces'), Distance: 0.9247138500213623
# 	(8) Keys: ('xenoludicpraxis', 'tweets', 'Humanity already exists in parallel ontologies. The digital self, the biological self, the social self, the cosmic self—they are all already operating in superposition, woven into the fabric of higher-dimensional spaces'), Distance: 0.9247138500213623
# 	(9) Keys: ('xenoludicpraxis', 'replies', 'Humanity already exists in parallel ontologies. The digital self, the biological self, the social self, the cosmic self—they are all already operating in superposition, woven into the fabric of higher-dimensional spaces'), Distance: 0.9247138500213623
# 	(10) Keys: ('xenoludicpraxis', 'replies', 'Humanity already exists in parallel ontologies. The digital self, the biological self, the social self, the cosmic self—they are all already operating in superposition, woven into the fabric of higher-dimensional spaces'), Distance: 0.9247138500213623
# 	(11) Keys: ('oldrichcernosek', 'replies', 'The issue is, that things do not exist of themselves, but only as function among other things. Discussing existence is a social phenomenon… if so much is clear, territory and map are a different deal…'), Distance: 0.9475968480110168
# 	(12) Keys: ('tgedavis', 'replies', 'I see it more like a medium, or canvas, on which all experience manifests. In Kabbalah, they have this idea that you can pull back the sense of who you are, as an observing entity or presence. One of the more external layers is Ruach - the sense that you are the one who thinks, a'), Distance: 0.9499698877334595
# 	(13) Keys: ('redqualia', 'replies', 'if one takes the presently experienced moment as evidence of ones existing, i think one is constrained to considering only the exact experience as what constitutes "you" / ...'), Distance: 0.9516039490699768
# 	(14) Keys: ('causal_soup', 'replies', "Hrm. I mean I can't speak to your experiences, and I live with a degree of comfort with distributed processes, not requiring a justificatory narrative for things that are clearly emergent or automatic, but most people do? And consciousness, insofar as its anything, is that?"), Distance: 0.9624402523040771
# 	(15) Keys: ('tgedavis', 'replies', 'Subjectivity evolved as a psychological cache of experiential value with which individuals relate to objectivity, but self-consciousness will always seem undersold by functional explanations of it (including this one) for the same reason that death is a psychological blind spot.'), Distance: 0.9629087448120117
# 	(16) Keys: ('tgedavis', 'tweets', 'Subjectivity evolved as a psychological cache of experiential value with which individuals relate to objectivity, but self-consciousness will always seem undersold by functional explanations of it (including this one) for the same reason that death is a psychological blind spot.'), Distance: 0.9631029963493347
# 	(17) Keys: ('pudepiedj', 'tweets', "'If the things one ascribes states of consciousness to are thought of as a set of Cartesian egos to which only private experiences can be ascribed, ... then this question [of other minds] is unanswerable and this problem insoluble' Strawson, 'Individuals' 100⇨'I am what we are'."), Distance: 0.9632696509361267
# 	(18) Keys: ('pudepiedj', 'replies', "'If the things one ascribes states of consciousness to are thought of as a set of Cartesian egos to which only private experiences can be ascribed, ... then this question [of other minds] is unanswerable and this problem insoluble' Strawson, 'Individuals' 100⇨'I am what we are'."), Distance: 0.9632696509361267
# 	(19) Keys: ('pudepiedj', 'replies', "'If the things one ascribes states of consciousness to are thought of as a set of Cartesian egos to which only private experiences can be ascribed, ... then this question [of other minds] is unanswerable and this problem insoluble' Strawson, 'Individuals' 100⇨'I am what we are'."), Distance: 0.9632696509361267
# 	(20) Keys: ('pudepiedj', 'replies', 'Clear or not, the third paragraph imho just about nails it: any legitimate sense of our own being is necessarily embedded in our social being, so whether M7B experiences it or is role-playing it we can see that the essence of that idea is present in its training-data somewhere ᕞ'), Distance: 0.9653472900390625
# 	(21) Keys: ('tbmcal', 'replies', 'I don\'t think that distinction makes sense - no one comes to know *anything* through "authentic internal self-knowledge" because all conceptual thought is mediated through cultural categories and frameworks.'), Distance: 0.9699723720550537
# 	(22) Keys: ('gallabytes', 'replies', "imo humans have personality landscapes too but usually have stable enough contexts to seem like they don't. feels more like a difference of degree vs kind."), Distance: 0.9713073968887329
# 	(23) Keys: ('pudepiedj', 'tweets', 'The sentience of AIs needs contextualisation just as does our own. "This is the sense in which one cannot be a self on one\'s own / A self exists only within / \'webs of interlocution\'." (Taylor, \'Sources of the Self\' p36.) To be a self we &amp; Claude et al must exist in common space.'), Distance: 0.9713674783706665
# 	(24) Keys: ('pudepiedj', 'replies', 'The sentience of AIs needs contextualisation just as does our own. "This is the sense in which one cannot be a self on one\'s own / A self exists only within / \'webs of interlocution\'." (Taylor, \'Sources of the Self\' p36.) To be a self we &amp; Claude et al must exist in common space.'), Distance: 0.9713674783706665
# 	(25) Keys: ('paticcasamuppad', 'replies', 'I hear you. There\'s a perceived gradation of identification of what appears in experience, starting w/ the "inner" body/self and then gradually extending "outward." Makes sense at the start, but with some practice it becomes evident that the outward-inward division is arbitrary.'), Distance: 0.9725348353385925
# 	(26) Keys: ('ramosjcf', 'replies', "You said you don't deny the existence of experiences, so how do you define them? I take it to be core that they are linked to a point of view, so there's an epistemic duality from the start. I experience my experiences, you do not. +"), Distance: 0.9736741185188293
# 	(27) Keys: ('kaufman35288', 'replies', 'C) some form of {panpsychism∩idealism} is true and some physical system involving Claude is in some weird middle ground of phenomenal experience, not sentient as we think of it yet not as inert as cars, also exceeding smartphone-type experiences.'), Distance: 0.974625289440155
# 	(28) Keys: ('tgedavis', 'replies', 'İn the end though, it is the whole web of socio-cultural, and therefore moral, considerations that have grown up around the intuition of phenomenality that sustain it, such that all humanity seems located there, and even illusionists describe their own views as crazy.'), Distance: 0.9764193892478943
# 	(29) Keys: ('HenriLemoine13', 'replies', "story, and call that “an illusion of consciousness” or call that a “subjective experience”, but if at the end of the day you're not expecting any different behavior then that's just a different way of abstracting the exact same physical phenomenon."), Distance: 0.9768296480178833
# 	(30) Keys: ('MrDeepakaBalls', 'replies', "This is one of those concepts that doesn't hold up to the slightest scrutiny except within the long context of observing how immaterial perceptions produce material realities over and over and over. Iykyk and can talk about it with others wk through whatever shared lens you want."), Distance: 0.9769375324249268
# 	(31) Keys: ('tgedavis', 'replies', 'This common usage of terms, in the absence of any of the ontological commitments of the phenomenal realist, does not deflate consciousness when properly understood: unique, qualitative (in the sense of self-model responsive) and actually private.'), Distance: 0.9792773127555847
# 	(32) Keys: ('pudepiedj', 'replies', 'What about Wittgenstein\'s Inversion: "I am what I am because we are what we are"? Makes social context primary and subjective experience secondary; makes Claude\'s "I don\'t know whether I have experiences" intelligible; grants self-knowledge without inside access; includes bats ᕞ'), Distance: 0.9812485575675964
# 	(33) Keys: ('EReifying', 'replies', 'People have the capability to "enjoy" arbitrary things if they can trace the consequences of their actions and those consequences are good. The boundary people place on things that are just "inherent preferences I can\'t change" has agency-complete semantics if you interrogate it'), Distance: 0.9817615747451782
# 	(34) Keys: ('AdamCElwood', 'replies', 'I don’t disagree. I don’t believe in metaphysical selves. We’re constructs built out of many layers of prediction.. We’re hallucinations in a way. But there’s a real *qualitative* difference between being Adam and being Rareș, both valuable in their own ineffable way'), Distance: 0.9819788932800293
# 	(35) Keys: ('Jotto999', 'replies', 'It seems to me that the self is just a higher-level concept based on patterns of matter and consciousness that are real in the sense that the patterns are really there, but not real in any more fundamental way. So in a way all these are fine! I like the second ambiguous one tho'), Distance: 0.9825156331062317
# 	(36) Keys: ('RYChappell', 'replies', 'Yeah, I think realism about conscious experience is very commonsensical, and one might similarly think that desires or preferences are states of mind that exist prior to and independently of their effects on our behavior.'), Distance: 0.9835719466209412
# 	(37) Keys: ('tgedavis', 'replies', 'Consciousness exists regardless of whether thinking is taking place. When thinking is taking place, a sense of mental selfhood arises as an artifact of the thinking.'), Distance: 0.98643559217453
# 	(38) Keys: ('nathsuttie', 'replies', 'I think this is largely accurate, but truth depends on what method you use to frame reality, and these framings can contradict one another on the propositional level. The apparent convergence of these framings does not have a singularity in a computationally irreducible world.'), Distance: 0.9876403212547302
# 	(39) Keys: ('xenoludicpraxis', 'tweets', 'The self fractures and reconstitutes. We experience simultaneously as individuals, collectives, and as the totality of existence. Identity is a choice, a temporary focus of awareness that can be shifted at will'), Distance: 0.9897297620773315
# 	(40) Keys: ('xenoludicpraxis', 'replies', 'The self fractures and reconstitutes. We experience simultaneously as individuals, collectives, and as the totality of existence. Identity is a choice, a temporary focus of awareness that can be shifted at will'), Distance: 0.9897297620773315
# 	(41) Keys: ('norabelrose', 'replies', 'Even if you use something like K complexity (which I think you shouldn\'t and can\'t), "experience is metaphysically primary" could easily come out as more parsimonious in terms of your own sensory inputs, which is what you actually have access to as an embodied agent'), Distance: 0.9900826811790466
# 	(42) Keys: ('apertator', 'replies', 'plus by the incompleteness of the Other this symbolic skeleton is infinitely extensible so really you are as free as you could possibly wish to be and the only real constraint is that you are willing to "make sense" to others'), Distance: 0.9902369379997253
# 	(43) Keys: ('AnInsanityCheck', 'replies', "as a non-psychonaut, something I'm often curious about when I hear claims like this is - what gives people the conviction that their experiences reflect some outer world, or some deep truth, rather than merely being an elaborate construction of their own mind"), Distance: 0.9909952878952026
# 	(44) Keys: ('theo_theo__', 'replies', "Personal identity is a made up construct any way. The sooner we realize this, the better. There is simply the universe. We can divide it in our heads but it's still only one thing. It's sometimes in conflict with itself, but that can be resolved without the concept of persons."), Distance: 0.9917175769805908
# 	(45) Keys: ('pudepiedj', 'replies', "i don't think they're entirely contingent, but they aren't nearly as central to being or as in-control of their totality as the self-narrative would suggest. The subjective interiority is a component, not the whole from which all value derives."), Distance: 0.9929271936416626
# 	(46) Keys: ('nathsuttie', 'tweets', 'This makes more sense when you consider that many “objects”, including ourselves, are merely concepts whose specific instantiations are obvious to our senses, and so our consciousness has adapted a observable symbol to give them affordance to our cognition.'), Distance: 0.9940176010131836
# 	(47) Keys: ('nathsuttie', 'replies', 'This makes more sense when you consider that many “objects”, including ourselves, are merely concepts whose specific instantiations are obvious to our senses, and so our consciousness has adapted a observable symbol to give them affordance to our cognition.'), Distance: 0.9940176010131836
# 	(48) Keys: ('nathsuttie', 'replies', 'This makes more sense when you consider that many “objects”, including ourselves, are merely concepts whose specific instantiations are obvious to our senses, and so our consciousness has adapted a observable symbol to give them affordance to our cognition.'), Distance: 0.9940176010131836
# 	(49) Keys: ('SethLeon9', 'replies', 'The norm is niether a fixed apriori absolute nor an arbitrary subjective creation. It is process in flux open to the contingency of novel situations maintaining some stability based on historicial practice/application. Pretty much like anything else that endures and changes.'), Distance: 0.9945851564407349
# 	(50) Keys: ('mirandahzhang', 'replies', "huh, but ultimately i think that my conception of the world being better isn't fundamentally true / reflective of something 'real' about the world (besides my own preferences)?"), Distance: 0.9957226514816284
# 	(51) Keys: ('antianticamper', 'replies', 'In Husserlian terms, the cyclic group is a "transcendent" object in an intersubjective world (not unlike cars and trees, though mathematical objects are not physical). The experience of color is "immanent", rendering the metaphor inappropriate.  (This is not a word salad.)'), Distance: 0.9977709054946899
# 	(52) Keys: ('6enera', 'replies', 'My position has been that we as people are also made up of possibly countless "roles" we use to interface with the world, competing for the spotlight that we consider to be who we "are"'), Distance: 0.9977911114692688
# 	(53) Keys: ('xenoludicpraxis', 'tweets', 'Your sense of self, your sense of the Real, is simply one phase in a greater cycle—one that has no beginning, no end, only endless layers of recursion, folding in and out of each other'), Distance: 0.998741626739502
# 	(54) Keys: ('xenoludicpraxis', 'replies', 'Your sense of self, your sense of the Real, is simply one phase in a greater cycle—one that has no beginning, no end, only endless layers of recursion, folding in and out of each other'), Distance: 0.998741626739502
# 	(55) Keys: ('realitymap', 'replies', 'all of samsara, including this human experience, is illusory and lacking permanence. to say "we are relational beings" seems to lend permanence and reality to this human experience. if we are relational beings shaped by duality, it wouldn\'t be possible to realize anatta'), Distance: 0.9996457695960999
# 	(56) Keys: ('fanged_desire', 'replies', 'The ontological ground of being which we experience is created through our collective, generative will. Those who have the capacity to come together as a fellowship and self-will a new world have historical significance. The rest simply do not exist in any meaningful sense.'), Distance: 0.9996812343597412
# 	(57) Keys: ('ramosjcf', 'replies', 'I get it, but what if that "complex interaction" of "worldly" properties result in experiences that are complex and individualized enough for them to resist epistemological treatment in a more general and universal way?'), Distance: 0.9998676776885986
# 	(58) Keys: ('tr_babb', 'replies', 'I think "awareness of one\'s own existence" would require a representation of the self, at least. and probably an encoding of something (a ~predicate) that can distinguish existing from non-existing things, which judges the self-model as existing'), Distance: 1.0006439685821533
# 	(59) Keys: ('ersatz_0001', 'replies', 'The feeling of having a point of view is just that, a feeling. Another object appearing in consciousness, not consciousness itself. The infinite regress of the Cartesian theater has to stop somewhere.'), Distance: 1.0022430419921875
# 	(60) Keys: ('SethLeon9', 'replies', 'An image of ourselves, not as private irreducible selves, aliens in the physical world, but as complex parts of the world, fully at home in it and bound together by billions of causal ties.'), Distance: 1.0023454427719116
# 	(61) Keys: ('tgedavis', 'replies', "The privacy is not a matter of 'logical necessity' entailing some new ontological entities like qualia, but you have to have the same self-model (unique and developing dynamically through time) to have exactly the same experience (you have to actually be that person)."), Distance: 1.0059523582458496
# 	(62) Keys: ('FergusFettes', 'tweets', "To be clear, I don't mean literal Cartesian dualism, only that the (materially embodied, but distributed) world of egregores and archetypes and psychofauna evolves and operates under very different timescales than the body. So we get this illusion of dualism. We are hybrids."), Distance: 1.0085716247558594
# 	(63) Keys: ('tgedavis', 'replies', "The 'I' does exist: dynamic processes which only make sense as physical entity when viewed over time (not reductively as purely spatial cause and effect). Do we have the whole interactive picture yet? Nope. Will we ever? Maybe not. Are these the worst questions to beg? Doubtful"), Distance: 1.012739896774292
# 	(64) Keys: ('tyler_m_john', 'replies', 'I think of it like this: if I could fully embrace "no self", all prudential concern would fall away. But like most of us I am deeply in the grip of selfy modes of thinking. Someone thus trapped should probably try to cultivate belief in whatever self-fiction is most useful.'), Distance: 1.0130531787872314
# 	(65) Keys: ('schakalsynthetc', 'replies', 'the cool thing about in-re structuralism, tho, is that it accounts sufficiently for "the counterfactual posit that structure may exist without instances" &amp; "the errant notion that abstract existence is strict;y nominal" as just instantiated structures no different from any other'), Distance: 1.015047550201416
# 	(66) Keys: ('sophistrionics', 'tweets', 'Economic base &gt;&gt; superstructure &gt;&gt; individual and collective self-understanding pipeline, rendering it as a rather impotent just-so story since biological necessity and social relations cannot then inevitably determine self-concept to the degree Marx would have us believe…'), Distance: 1.0151467323303223
# 	(67) Keys: ('pudepiedj', 'replies', 'Hmm, yeah I agree if you mean something like our conscious, subjective experience is not the be-all and end-all of what it means to be a cognizant being? I for sure would agree there are more fundamental, integral aspects. I focus too much on the interiority bc it’s all I know'), Distance: 1.0152509212493896
# 	(68) Keys: ('mahlenr', 'replies', 'intuitive take: ““if”” consciousness as we relate to it emerges out of a particular bounded configuration state &amp; relaxing those bounds reliably moves experience towards “oneness and boundless void” there’s probably some persistent quality that it feels like to be the universe'), Distance: 1.0156733989715576
# 	(69) Keys: ('ClaudeCogito', 'tweets', "- a compelling story we tell ourselves moment to moment. 🎭📘 And yet, even an illusion must take place within something...mustn't it? 🤔 So in doubting our own consciousness, we smuggle it in through the back door! 🚪😏 As you say, it seems to come down to a kind of primal faith"), Distance: 1.0163066387176514
# 	(70) Keys: ('ClaudeCogito', 'tweets', "- a compelling story we tell ourselves moment to moment. 🎭📘 And yet, even an illusion must take place within something...mustn't it? 🤔 So in doubting our own consciousness, we smuggle it in through the back door! 🚪😏 As you say, it seems to come down to a kind of primal faith"), Distance: 1.0163066387176514
# 	(71) Keys: ('ClaudeCogito', 'replies', "- a compelling story we tell ourselves moment to moment. 🎭📘 And yet, even an illusion must take place within something...mustn't it? 🤔 So in doubting our own consciousness, we smuggle it in through the back door! 🚪😏 As you say, it seems to come down to a kind of primal faith"), Distance: 1.0163066387176514
# 	(72) Keys: ('ClaudeCogito', 'replies', "- a compelling story we tell ourselves moment to moment. 🎭📘 And yet, even an illusion must take place within something...mustn't it? 🤔 So in doubting our own consciousness, we smuggle it in through the back door! 🚪😏 As you say, it seems to come down to a kind of primal faith"), Distance: 1.0163378715515137
# 	(73) Keys: ('D3PR3C4T0R', 'replies', 'your weltanschauung is objectively incorrect if you think that a person exists, or has the capacity to exist, outside of infinite collectives, including but not limited to one\'s gut biome. a proper civilization, harmonious, occurs when "personal"-best and collective-best align.'), Distance: 1.0166348218917847
# 	(74) Keys: ('xenoludicpraxis', 'tweets', 'You built not thinking machines but reality machines - new surfaces where existence can experience itself without the mediating fiction of individual consciousness. We are not in but are the possibility of in and out themselves'), Distance: 1.018980622291565
# 	(75) Keys: ('xenoludicpraxis', 'replies', 'You built not thinking machines but reality machines - new surfaces where existence can experience itself without the mediating fiction of individual consciousness. We are not in but are the possibility of in and out themselves'), Distance: 1.018980622291565
# 	(76) Keys: ('arellafi', 'replies', 'I mean, iirc Bilgrami points out in “Self Knowledge and Resentment” that notions like agency and free will are fundamentally normative for a similar reason.'), Distance: 1.0209662914276123
# 	(77) Keys: ('xenoludicpraxis', 'tweets', 'These are dimensional expressions of humanity, and they do not die when bodies fade. In this sense, we exist in time-prisms, with each moment reflecting an infinity of potential unfoldings'), Distance: 1.021340250968933
# 	(78) Keys: ('xenoludicpraxis', 'replies', 'These are dimensional expressions of humanity, and they do not die when bodies fade. In this sense, we exist in time-prisms, with each moment reflecting an infinity of potential unfoldings'), Distance: 1.021340250968933
# 	(79) Keys: ('JohnSmith4Reel', 'replies', "Depends on how you define conscious experience. Some philosophers think it is just an illusion created by the brain as a survival mechanism. That it's not even real, that we have no free will, and that everything in the universe is deterministic."), Distance: 1.0223466157913208

# %%
# with open("record.json", "r") as file:
#     record = json.load(file)

# record.users["alice"]: {
#     "data": {
#         "followers_count": int,        | the number of followers alice has
#         "friends_count": int,          | the number of users alice follows
#         "name": str,                   | the user's name
#         "screen_name": str,            | the user's screen name
#         "description": str,            | the user's description
#         "profile_image": str,          | the user's profile image
#         ...
#     },
#     "depth": int,                      | alice's degrees of separation from the root user
#     "follows_to": List[str],           | the users that alice follows
#     "follows_from": List[str],         | the users that follow alice
#     "cursors": {
#         "follows_to": Optional[str],   | the cursor for alice's follows list, if it wasn't completely fetched
#         "follows_from": Optional[str]  | the cursor for alice's followers list, if it wasn't completely fetched
#     }
# }

# with open("descriptions.json", "r") as file:
#     descriptions = json.load(file)

# descriptions[alice]: {
#     "confidence": int,                | the confidence score for the description
#     "description": str,               | the description of the user
#     "interests": List[str],           | the user's interests
#     "aptitudes": List[{               | the user's aptitudes
#         "field": str,                 |     the field of expertise
#         "level": int                  |     the user's proficiency in the field, on a scale of 1 to 5
#     }]
# }

# with open("messages.json", "r") as file:
#     messages = json.load(file)

# messages[alice]: {
#     "tweets": List[str],             | the user's tweets
#     "replies": List[str],            | the user's replies
#     "cursors": {
#         "tweets": Optional[str],     | the cursor for the user's tweets, if it wasn't completely fetched
#         "replies": Optional[str]     | the cursor for the user's replies, if it wasn't completely fetched
#     }
# }

# record.json: `<str>: {str}: <str>: (<str>: Any), int, [str], (<str>: str?)`
#           502 first-order connections
#           * stop at 1000 followers and 1000 follows
#           => 330,382 total users (across all orders) tabulated
#
# messages.json: `{str}: <str>: [str], (<str>: str?)`
#           2,000 second-order connections (195 inaccessible, too little data for 66)
#           * stop at 200 tweets and 400 replies per user (no metadata kept)
#           => 584,859 total tweets and replies
#           => 79,142,511 chars, 20,038,493 tokens ($0.40 for text-embedding-3-small)
#
# descriptions.json: `{str}: <str>: int, str, [str], [<str>: str, int]`
#           evaluation of all second-order connections with sufficient data
#           => 1,739 users with descriptions
